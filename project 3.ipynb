# %%
#Intution :
      #Higest gain Marks Student - Rahul
      # Highest marks - 85
       # Highest studytime student - tarun
       # Highest study time - 7 hours
       # Highest sleep time student - Suman

# %%
import pandas as pd 
df = pd.read_csv("project.3.csv")
print (df)
# Out:
#       Name  Study Hours  Sleep Hours  Marks
# 0     Aman          2.0          7.0   45.0
# 1    Rohit          5.0          6.0   65.0
# 2    Suman          3.0          8.0   55.0
# 3     Neha          6.0          6.0   72.0
# 4    Priya          NaN          7.0   60.0
# 5    Arjun          7.0          5.0   78.0
# 6    Karan          1.0          9.0   40.0
# 7     Riya          5.0          NaN    NaN
# 8    Vikas          6.0          7.0   75.0
# 9   Anjali          3.0          8.0   58.0
# 10  Deepak          4.0          6.0   62.0
# 11   Pooja          2.0          7.0   50.0
# 12   Rahul          8.0          5.0   85.0
# 13   Sneha          5.0          7.0   70.0
# 14  Manish          6.0          6.0   74.0
# 15   Kavya          7.0          6.0   80.0
# 16   Nitin          2.0          8.0    NaN
# 17  Simran          4.0          7.0   63.0
# 18    Amit          5.0          6.0   69.0
# 19   Meena          3.0          8.0   57.0
# ...

# %%
# find missing value
import pandas as pd 
df = pd.read_csv("project.3.csv")
df.isnull().sum() 
print (df.isnull().sum() )
# Out:
# Name           0
# Study Hours    2
# Sleep Hours    3
# Marks          2
# dtype: int64

# %%
# drop missing value
import pandas as pd 
df = pd.read_csv("project.3.csv") 
df = df.dropna()
print (df)
# Out:
#       Name  Study Hours  Sleep Hours  Marks
# 0     Aman          2.0          7.0   45.0
# 1    Rohit          5.0          6.0   65.0
# 2    Suman          3.0          8.0   55.0
# 3     Neha          6.0          6.0   72.0
# 5    Arjun          7.0          5.0   78.0
# 6    Karan          1.0          9.0   40.0
# 8    Vikas          6.0          7.0   75.0
# 9   Anjali          3.0          8.0   58.0
# 10  Deepak          4.0          6.0   62.0
# 11   Pooja          2.0          7.0   50.0
# 12   Rahul          8.0          5.0   85.0
# 13   Sneha          5.0          7.0   70.0
# 14  Manish          6.0          6.0   74.0
# 15   Kavya          7.0          6.0   80.0
# 17  Simran          4.0          7.0   63.0
# 18    Amit          5.0          6.0   69.0
# 19   Meena          3.0          8.0   57.0
# 20  Suresh          6.0          5.0   73.0
# 21  Ramesh          7.0          6.0   79.0
# 22   Komal          4.0          7.0   61.0
# ...

# %%
import pandas as pd 
df = pd.read_csv("project.3.csv") 
df.describe()
# Out:
#        Study Hours  Sleep Hours      Marks
# count    38.000000    37.000000  38.000000
# mean      4.605263     6.567568  66.105263
# std       1.778847     1.068242  11.479216
# min       1.000000     5.000000  40.000000
# 25%       3.000000     6.000000  58.500000
# 50%       5.000000     6.000000  66.500000
# 75%       6.000000     7.000000  75.000000
# max       8.000000     9.000000  85.000000

# %%
import pandas as pd 
df = pd.read_csv("project.3.csv") 
corr = df.corr(numeric_only=True)
print(corr)
# Out:
#              Study Hours  Sleep Hours     Marks
# Study Hours     1.000000    -0.861550  0.987215
# Sleep Hours    -0.861550     1.000000 -0.837605
# Marks           0.987215    -0.837605  1.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Study Hours"], df["Marks"])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
df.groupby("Name")["Marks"].mean().plot(kind="bar")
plt.title("Marks of Students")
plt.show()

# %%
Prediction                    Result  

 More study = high marks      : True 
 Sleep affects marks strongly : False 
 Study vs marks strong relation : True 
 Sleep moderate effect          : Weak
